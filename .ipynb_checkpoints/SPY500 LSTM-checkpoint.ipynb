# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import RobustScaler
plt.style.use("bmh")


# Technical Analysis library
import ta 
from ta import add_all_ta_features

from datetime import timedelta

# Neural Network library
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Cargar la Data

# %%
# SPY 500 Desde Enero 2015 a Enero 2020 tomado de Yahoo Finance

df= pd.read_csv('SPY.csv')

# %% [markdown]
# # Procesamiento de los datos

# %% [markdown]
# ### Conversión de fecha

# %%
df['Date'] = pd.to_datetime(df.Date)

# %%
df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2015-01-06  202.089996  202.720001  198.860001  199.820007  176.034042
# 1 2015-01-07  201.419998  202.720001  200.880005  202.309998  178.227661
# 2 2015-01-08  204.009995  206.160004  203.990005  205.899994  181.390289
# 3 2015-01-09  206.399994  206.419998  203.509995  204.250000  179.936707
# 4 2015-01-12  204.410004  204.600006  201.919998  202.649994  178.527176
#
#       Volume
# 0  209151400
# 1  125346700
# 2  147217800
# 3  158567300
# 4  144396100

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.shape
# Out:
# (1258, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1258 non-null   datetime64[ns]
#  1   Open       1258 non-null   float64
#  2   High       1258 non-null   float64
#  3   Low        1258 non-null   float64
#  4   Close      1258 non-null   float64
#  5   Adj Close  1258 non-null   float64
#  6   Volume     1258 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 68.9 KB

# %%
# Configuración del índice

df.set_index('Date', inplace=True)

# %%
df.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Borrar los valores NaN

df.dropna(inplace=True)

# %% [markdown]
# # Visualizar el S&P500

# %%
#Gráfica Precio vs Año

df['Close'].plot(figsize=(18,8))
plt.title('Precio de Cierre', size =24)
plt.xlabel('Año', size=18)
plt.ylabel('Precio de cierre ($)', size=18)
plt.show()

# %% [markdown]
# # Agregar Indicadores Técnicos

# %%
# Añadiendo los indicadores técnicos

df = ta.add_all_ta_features(df, open="Open", high="High", low="Low", close="Close", volume="Volume", fillna=True)

# %%
# Dropping 

df.drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)

# %%
# Visualizando el nuevo DF con los Indicadores Técnicos


df.tail()
# Out:
#                  Close    volume_adi  volume_obv  volume_cmf     volume_fi  \
# Date
# 2019-12-27  322.859985  1.079870e+10  1085656700    0.105757  3.173312e+07
# 2019-12-30  321.079987  1.076964e+10  1035927600    0.096838  1.455443e+07
# 2019-12-31  321.859985  1.081115e+10  1093004900    0.178432  1.883525e+07
# 2020-01-02  324.869995  1.086930e+10  1152156100    0.171860  4.157960e+07
# 2020-01-03  322.410004  1.087175e+10  1074446400    0.159139  8.330351e+06
#
#             volume_mfi  volume_em  volume_sma_em     volume_vpt  volume_nvi  \
# Date
# 2019-12-27   88.025346   2.662575       1.760237  154010.722514  3853.40702
# 2019-12-30   86.488155  -6.230282       1.377464 -284705.093884  3853.40702
# 2019-12-31   85.943193  -2.376256       1.398939 -135509.850962  3853.40702
# 2020-01-02   86.057580  10.253822       2.065658  691835.103412  3853.40702
# 2020-01-03   77.080011  -4.379895       1.183828  -35258.378597  3853.40702
#
#             ...  momentum_wr  momentum_ao  momentum_kama  momentum_roc  \
# Date        ...
# 2019-12-27  ...    -8.553265     7.428500     321.901882      2.975787
# 2019-12-30  ...   -24.749804     7.251321     321.798862      2.118178
# 2019-12-31  ...   -18.725923     6.819057     321.803857      1.491496
# 2020-01-02  ...    -0.186754     6.888472     322.307966      2.379298
# 2020-01-03  ...   -27.959456     6.498471     322.312398      0.910799
#
#             momentum_ppo  momentum_ppo_signal  momentum_ppo_hist  others_dr  \
# Date
# 2019-12-27     -2.040326             4.413225          -6.453551  -0.024778
# 2019-12-30     -2.995663             2.931448          -5.927111  -0.551322
# 2019-12-31     -2.687346             1.807689          -4.495035   0.242929
# 2020-01-02     -2.124180             1.021315          -3.145495   0.935192
# 2020-01-03      0.862338             0.989520          -0.127182  -0.757223
#
#             others_dlr  others_cr
# Date
# 2019-12-27   -0.024781  61.575405
# 2019-12-30   -0.552847  60.684604
# 2019-12-31    0.242635  61.074954
# 2020-01-02    0.930847  62.581315
# 2020-01-03   -0.760105  61.350212
#
# [5 rows x 84 columns]

# %%
df.shape
# Out:
# (1258, 84)

# %%
# Usaremos los últimos 1000 días de datos para obtener una representación más precisa del clima actual del mercado

df = df.tail(1000)

# %%
df.describe()
# Out:
#              Close    volume_adi    volume_obv   volume_cmf     volume_fi  \
# count  1000.000000  1.000000e+03  1.000000e+03  1000.000000  1.000000e+03
# mean    255.473650  7.292336e+09 -3.941761e+08     0.122508 -1.164916e+07
# std      33.016254  2.280901e+09  9.526205e+08     0.161261  8.275191e+07
# min     182.860001  1.658318e+09 -2.742146e+09    -0.294474 -6.474199e+08
# 25%     226.567501  5.187780e+09 -1.205231e+09     0.011367 -2.387412e+07
# 50%     260.875000  8.025476e+09 -1.469954e+08     0.124701  8.398214e+06
# 75%     281.557488  8.864401e+09  4.377888e+08     0.233538  2.770301e+07
# max     324.869995  1.087175e+10  1.171156e+09     0.539894  1.432270e+08
#
#         volume_mfi    volume_em  volume_sma_em    volume_vpt   volume_nvi  \
# count  1000.000000  1000.000000    1000.000000  1.000000e+03  1000.000000
# mean     52.270500     0.193157       0.174109 -6.599893e+04  2382.307440
# std      15.503311     6.049564       1.670858  1.781605e+06   700.282207
# min       9.863398   -35.064851     -11.553934 -1.610684e+07  1383.924327
# 25%      40.316326    -1.342969      -0.254084 -3.386339e+05  1843.374616
# 50%      52.612229     0.275721       0.327132  9.183097e+04  2081.450350
# 75%      63.223160     2.356672       0.940847  4.919671e+05  2931.664780
# max      94.819711    30.929803       6.326836  1.246899e+07  3865.787820
#
#        ...  momentum_wr  momentum_ao  momentum_kama  momentum_roc  \
# count  ...  1000.000000  1000.000000    1000.000000   1000.000000
# mean   ...   -32.483394     1.676668     254.689477      0.613356
# std    ...    28.688073     5.131810      32.910163      2.561433
# min    ...  -100.000000   -22.150324     189.383326    -13.155944
# 25%    ...   -54.144033    -0.890712     224.918624     -0.428091
# 50%    ...   -23.025839     2.703821     261.139940      0.916378
# 75%    ...    -7.468677     4.967084     280.326220      2.115437
# max    ...    -0.000000    13.486205     322.312398     10.514643
#
#        momentum_ppo  momentum_ppo_signal  momentum_ppo_hist    others_dr  \
# count   1000.000000          1000.000000        1000.000000  1000.000000
# mean      -1.216682            -1.193064          -0.023618     0.056774
# std        8.297074             6.869301           4.185383     0.807069
# min      -16.571195           -14.408060         -10.245027    -4.182254
# 25%       -7.229085            -6.128925          -2.540146    -0.243194
# 50%       -2.092018            -1.975322          -0.354800     0.053874
# 75%        2.749070             2.281327           2.159887     0.460114
# max       31.164373            22.085693          19.299289     5.052487
#
#         others_dlr    others_cr
# count  1000.000000  1000.000000
# mean      0.053498    27.851887
# std       0.808480    16.522997
# min      -4.272228    -8.487642
# 25%      -0.243490    13.385794
# 50%       0.053860    30.554995
# 75%       0.459059    40.905554
# max       4.928991    62.581315
#
# [8 rows x 84 columns]

# %% [markdown]
# # Scaling

# %% [markdown]
# #### Ajustando las escala de los precios de cierre por separado

# %% [markdown]
# Utilizando RobustScaler para escalar los datos buscando que los valores atípicos extremos tengan poco efecto

# %%
close_scaler = RobustScaler()

close_scaler.fit(df[['Close']])
# Out:
# RobustScaler()

# %%
scaler = RobustScaler()
df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns, index=df.index)

df.tail(10)
# Out:
#                Close  volume_adi  volume_obv  volume_cmf  volume_fi  \
# Date
# 2019-12-19  1.091562    0.753435    0.802274    0.514651   0.898166
# 2019-12-20  1.088471    0.754986    0.712718    0.438203   0.677319
# 2019-12-23  1.097382    0.748390    0.744970    0.248236   0.629214
# 2019-12-24  1.097564    0.748746    0.757307    0.092868   0.516627
# 2019-12-26  1.128660    0.757026    0.776120    0.115637   0.565967
# 2019-12-27  1.127205    0.754286    0.750236   -0.085266   0.452427
# 2019-12-30  1.094835    0.746382    0.719969   -0.125411   0.119359
# 2019-12-31  1.109020    0.757673    0.754708    0.241845   0.202358
# 2020-01-02  1.163757    0.773488    0.790710    0.212265   0.643335
# 2020-01-03  1.119022    0.774154    0.743413    0.155008  -0.001316
#
#             volume_mfi  volume_em  volume_sma_em  volume_vpt  volume_nvi  ...  \
# Date                                                                      ...
# 2019-12-19    0.911931   0.092007       0.472443    0.314070    1.622691  ...
# 2019-12-20    1.343301   0.129270       0.980082    0.216607    1.622691  ...
# 2019-12-23    1.664868   0.128612       1.944213   -0.106933    1.628092  ...
# 2019-12-24    1.553912  -0.194409       1.296194   -0.012334    1.628202  ...
# 2019-12-26    1.549012   1.168366       1.523244    0.088308    1.628202  ...
# 2019-12-27    1.545963   0.645158       1.199320    0.074861    1.628202  ...
# 2019-12-30    1.478857  -1.758550       0.878989   -0.453330    1.628202  ...
# 2019-12-31    1.455066  -0.716820       0.896961   -0.273706    1.628202  ...
# 2020-01-02    1.460060   2.697046       1.454917    0.722373    1.628202  ...
# 2020-01-03    1.068143  -1.258397       0.716941   -0.153009    1.628202  ...
#
#             momentum_wr  momentum_ao  momentum_kama  momentum_roc  \
# Date
# 2019-12-19     0.480941     0.744960       1.022639      1.081268
# 2019-12-20     0.314301     0.782432       1.033913      0.809873
# 2019-12-23     0.355392     0.803415       1.051578      0.798951
# 2019-12-24     0.354127     0.779570       1.065118      0.433849
# 2019-12-26     0.491204     0.783532       1.085931      0.774544
# 2019-12-27     0.310069     0.806563       1.096636      0.809666
# 2019-12-30    -0.036935     0.776316       1.094776      0.472493
# 2019-12-31     0.092124     0.702523       1.094866      0.226110
# 2020-01-02     0.489318     0.714373       1.103965      0.575154
# 2020-01-03    -0.105701     0.647795       1.104045     -0.002193
#
#             momentum_ppo  momentum_ppo_signal  momentum_ppo_hist  others_dr  \
# Date
# 2019-12-19      0.999224             0.772102           0.790409   0.506216
# 2019-12-20      1.849626             1.053796           2.091746  -0.151917
# 2019-12-23      1.450318             1.184401           1.010310   0.140620
# 2019-12-24      0.732874             1.118646          -0.395159  -0.072170
# 2019-12-26      0.249945             0.951450          -1.121235   0.680288
# 2019-12-27      0.005181             0.759614          -1.297597  -0.111831
# 2019-12-30     -0.090562             0.583427          -1.185590  -0.860499
# 2019-12-31     -0.059663             0.449809          -0.880895   0.268809
# 2020-01-02     -0.003223             0.356308          -0.593761   1.253105
# 2020-01-03      0.296082             0.352527           0.048429  -1.153261
#
#             others_dlr  others_cr
# Date
# 2019-12-19    0.505591   1.091562
# 2019-12-20   -0.152081   1.088471
# 2019-12-23    0.140627   1.097382
# 2019-12-24   -0.072227   1.097564
# 2019-12-26    0.679034   1.128660
# 2019-12-27   -0.111936   1.127205
# 2019-12-30   -0.863580   1.094835
# 2019-12-31    0.268701   1.109020
# 2020-01-02    1.248294   1.163757
# 2020-01-03   -1.158588   1.119022
#
# [10 rows x 84 columns]

# %% [markdown]
# # Visualizando los Precios con la escala

# %%
df['Close'].plot(figsize=(18,8))
plt.title("Precios al cierre")
plt.xlabel("Años")
plt.ylabel("Precios (Escalados)")
plt.show()

# %% [markdown]
# # Funciones auxiliares para preparar la data para Red LSTM

# %% [markdown]
# Esta función divide una secuencia de tiempo multivariante. Los valores de entrada serán los precios de cierre y los indicadores técnicos. Los valores X contendrán los precios de cierre anteriores y los indicadores. Las y contendrán los valores objetivo ( sólo los precios de cierre futuros).

# %%
def split_sequence(seq, n_steps_in, n_steps_out):
    X, y = [], []
    
    for i in range(len(seq)):
        end = i + n_steps_in
        out_end = end + n_steps_out
        if out_end > len(seq):
            break
        seq_x, seq_y = seq[i:end, :], seq[end:out_end, 0]
        
        X.append(seq_x)
        y.append(seq_y)
    
    return np.array(X), np.array(y)

# %% [markdown]
# Evaluar la red

# %%
def visualize_training_results(results):
   
    history = results.history
    plt.figure(figsize=(16,5))
    plt.plot(history['val_loss'])
    plt.plot(history['loss'])
    plt.legend(['val_loss', 'loss'])
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()
    
    plt.figure(figsize=(16,5))
    plt.plot(history['val_accuracy'])
    plt.plot(history['accuracy'])
    plt.legend(['val_accuracy', 'accuracy'])
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %% [markdown]
# Construir el cuerpo de nuestra Red

# %%
def layer_maker(n_layers, n_nodes, activation, drop=None, d_rate=.5):
    
    # Crea un número específico de capas ocultas para un RNN
    for x in range(1,n_layers+1):
        model.add(LSTM(n_nodes, activation=activation, return_sequences=True))
        try:
            if x % drop == 0:
                model.add(Dropout(d_rate))
        except:
            pass

# %% [markdown]
# Crea un DF con valores predichos para un rango específico de fechas.

# %%
def validater(n_per_in, n_per_out):
   
    predictions = pd.DataFrame(index=df.index, columns=[df.columns[0]])

    for i in range(1, len(df)-n_per_in, n_per_out):
        
        x = df[-i - n_per_in:-i]
        yhat = model.predict(np.array(x).reshape(1, n_per_in, n_features))

        yhat = close_scaler.inverse_transform(yhat)[0]

      
        pred_df = pd.DataFrame(yhat, 
                               index=pd.date_range(start=x.index[-1]+timedelta(days=1), 
                                                   periods=len(yhat), 
                                                   freq="B"),
                               columns=[x.columns[0]])

        
        predictions.update(pred_df)
        
    return predictions

# %% [markdown]
# Error cuadrático medio ( RMSE )

# %%
def val_rmse(df1, df2):
   
    df = df1.copy()
    

    df['close2'] = df2.Close
    df.dropna(inplace=True)
    df['diff'] = df.Close - df.close2  
   
    rms = (df[['diff']]**2).mean()
    return float(np.sqrt(rms))

# %% [markdown]
# # Dividiendo la data

# %%
# Número de períodos mirando hacia atrás para aprender 
n_per_in  = 270

# Número de períodos a predecir 
n_per_out = 180

#Funciones  
n_features = df.shape[1]

# Dividir los datos en secuencias 
X, y = split_sequence(df.to_numpy(), n_per_in, n_per_out)

# %% [markdown]
# # Modelado - LSTM (RNN)

# %% [markdown]
# Creando la Red Neuronal

# %%
# Instalación del modelo
model = Sequential()

# Activación
activ = "tanh"

# Capa entrada
model.add(LSTM(270, 
               activation=activ, 
               return_sequences=True, 
               input_shape=(n_per_in, n_features)))

# Capas ocultas
layer_maker(n_layers=2, 
            n_nodes=180, 
            activation=activ,
            drop=1,
            d_rate=.1)

# Capas ocultas final
model.add(LSTM(270, activation=activ))

# Capa salida
model.add(Dense(n_per_out))

# Resumen
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 270, 270)          383400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 270, 180)          324720
# _________________________________________________________________
# dropout (Dropout)            (None, 270, 180)          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 270, 180)          259920
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 270, 180)          0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 270)               487080
# _________________________________________________________________
# dense (Dense)                (None, 180)               48780
# =================================================================
# Total params: 1,503,900
# Trainable params: 1,503,900
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compilar los datos con especificaciones seleccionadas
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# %% [markdown]
# # Adaptación y formación de la RNN

# %%
res = model.fit(X, y, epochs=100, batch_size=32, validation_split=0.8)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 28s 7s/step - loss: 0.0565 - accuracy: 0.0091 - val_loss: 0.1426 - val_accuracy: 0.0045
# Epoch 2/100
# 4/4 [==============================] - 21s 6s/step - loss: 0.0185 - accuracy: 0.0636 - val_loss: 0.1475 - val_accuracy: 0.0068
# Epoch 3/100
# 4/4 [==============================] - 22s 6s/step - loss: 0.0121 - accuracy: 0.0636 - val_loss: 0.1510 - val_accuracy: 0.0045
# Epoch 4/100
# 4/4 [==============================] - 22s 6s/step - loss: 0.0077 - accuracy: 0.0545 - val_loss: 0.1432 - val_accuracy: 0.0045
# Epoch 5/100
# 4/4 [==============================] - 22s 6s/step - loss: 0.0053 - accuracy: 0.0909 - val_loss: 0.1456 - val_accuracy: 0.0045
# Epoch 6/100
# 4/4 [==============================] - 23s 7s/step - loss: 0.0040 - accuracy: 0.1545 - val_loss: 0.1461 - val_accuracy: 0.0045
# Epoch 7/100
# 4/4 [==============================] - 22s 6s/step - loss: 0.0033 - accuracy: 0.1273 - val_loss: 0.1425 - val_accuracy: 0.0023
# Epoch 8/100
# 4/4 [==============================] - 22s 6s/step - loss: 0.0028 - accuracy: 0.1818 - val_loss: 0.1516 - val_accuracy: 0.0023
# Epoch 9/100
# 4/4 [==============================] - 22s 6s/step - loss: 0.0025 - accuracy: 0.2273 - val_loss: 0.1485 - val_accuracy: 0.0045
# Epoch 10/100
# 4/4 [==============================] - 22s 6s/step - loss: 0.0023 - accuracy: 0.1364 - val_loss: 0.1546 - val_accuracy: 0.0023
# Epoch 11/100
# 4/4 [==============================] - 22s 6s/step - loss: 0.0021 - accuracy: 0.1364 - val_loss: 0.1540 - val_accuracy: 0.0023
# Epoch 12/100
# 4/4 [==============================] - 23s 7s/step - loss: 0.0020 - accuracy: 0.1273 - val_loss: 0.1576 - val_accuracy: 0.0023
# Epoch 13/100
# 4/4 [==============================] - 23s 7s/step - loss: 0.0018 - accuracy: 0.2273 - val_loss: 0.1567 - val_accuracy: 0.0023
# Epoch 14/100
# 4/4 [==============================] - 22s 6s/step - loss: 0.0017 - accuracy: 0.2182 - val_loss: 0.1594 - val_accuracy: 0.0023
# Epoch 15/100
# 4/4 [==============================] - 22s 6s/step - loss: 0.0016 - accuracy: 0.2636 - val_loss: 0.1599 - val_accuracy: 0.0023
# Epoch 16/100
# 4/4 [==============================] - 21s 6s/step - loss: 0.0016 - accuracy: 0.1636 - val_loss: 0.1594 - val_accuracy: 0.0023
# Epoch 17/100
# 4/4 [==============================] - 21s 6s/step - loss: 0.0015 - accuracy: 0.1727 - val_loss: 0.1592 - val_accuracy: 0.0023
# Epoch 18/100
# 4/4 [==============================] - 21s 6s/step - loss: 0.0014 - accuracy: 0.2455 - val_loss: 0.1607 - val_accuracy: 0.0023
# Epoch 19/100
# 4/4 [==============================] - 21s 6s/step - loss: 0.0013 - accuracy: 0.1909 - val_loss: 0.1596 - val_accuracy: 0.0023
# Epoch 20/100
# 4/4 [==============================] - 21s 6s/step - loss: 0.0013 - accuracy: 0.2455 - val_loss: 0.1631 - val_accuracy: 0.0023
# Epoch 21/100
# 4/4 [==============================] - 22s 6s/step - loss: 0.0012 - accuracy: 0.1636 - val_loss: 0.1592 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 4/4 [==============================] - 21s 6s/step - loss: 0.0012 - accuracy: 0.1636 - val_loss: 0.1623 - val_accuracy: 0.0023
# Epoch 23/100
# 4/4 [==============================] - 22s 6s/step - loss: 0.0011 - accuracy: 0.1909 - val_loss: 0.1619 - val_accuracy: 0.0023
# Epoch 24/100
# 4/4 [==============================] - 21s 6s/step - loss: 0.0011 - accuracy: 0.1364 - val_loss: 0.1642 - val_accuracy: 0.0023
# Epoch 25/100
# 4/4 [==============================] - 22s 6s/step - loss: 0.0010 - accuracy: 0.2182 - val_loss: 0.1629 - val_accuracy: 0.0023
# Epoch 26/100
# 4/4 [==============================] - 21s 6s/step - loss: 9.9214e-04 - accuracy: 0.2091 - val_loss: 0.1642 - val_accuracy: 0.0000e+00
# Epoch 27/100
# 4/4 [==============================] - 22s 6s/step - loss: 9.7914e-04 - accuracy: 0.2091 - val_loss: 0.1657 - val_accuracy: 0.0000e+00
# Epoch 28/100
# 4/4 [==============================] - 21s 6s/step - loss: 9.7164e-04 - accuracy: 0.2000 - val_loss: 0.1639 - val_accuracy: 0.0000e+00
# Epoch 29/100
# 4/4 [==============================] - 22s 6s/step - loss: 9.7510e-04 - accuracy: 0.2182 - val_loss: 0.1657 - val_accuracy: 0.0000e+00
# Epoch 30/100
# 4/4 [==============================] - 21s 6s/step - loss: 9.4720e-04 - accuracy: 0.2182 - val_loss: 0.1644 - val_accuracy: 0.0000e+00
# Epoch 31/100
# 4/4 [==============================] - 21s 6s/step - loss: 9.5373e-04 - accuracy: 0.1727 - val_loss: 0.1691 - val_accuracy: 0.0023
# Epoch 32/100
# 4/4 [==============================] - 21s 6s/step - loss: 9.3440e-04 - accuracy: 0.2182 - val_loss: 0.1701 - val_accuracy: 0.0023
# Epoch 33/100
# 4/4 [==============================] - 21s 6s/step - loss: 9.1265e-04 - accuracy: 0.1636 - val_loss: 0.1701 - val_accuracy: 0.0000e+00
# Epoch 34/100
# 4/4 [==============================] - 22s 6s/step - loss: 8.6864e-04 - accuracy: 0.2091 - val_loss: 0.1732 - val_accuracy: 0.0023
# Epoch 35/100
# 4/4 [==============================] - 22s 6s/step - loss: 8.7352e-04 - accuracy: 0.2000 - val_loss: 0.1724 - val_accuracy: 0.0023
# Epoch 36/100
# 4/4 [==============================] - 22s 6s/step - loss: 8.3910e-04 - accuracy: 0.2091 - val_loss: 0.1765 - val_accuracy: 0.0023
# Epoch 37/100
# 4/4 [==============================] - 22s 6s/step - loss: 8.2698e-04 - accuracy: 0.2091 - val_loss: 0.1728 - val_accuracy: 0.0023
# Epoch 38/100
# 4/4 [==============================] - 22s 6s/step - loss: 8.4048e-04 - accuracy: 0.2182 - val_loss: 0.1745 - val_accuracy: 0.0023
# Epoch 39/100
# 4/4 [==============================] - 22s 6s/step - loss: 8.2956e-04 - accuracy: 0.1818 - val_loss: 0.1787 - val_accuracy: 0.0023
# Epoch 40/100
# 4/4 [==============================] - 21s 6s/step - loss: 8.5774e-04 - accuracy: 0.2000 - val_loss: 0.1804 - val_accuracy: 0.0023
# Epoch 41/100
# 4/4 [==============================] - 21s 6s/step - loss: 9.1628e-04 - accuracy: 0.1909 - val_loss: 0.1785 - val_accuracy: 0.0045
# Epoch 42/100
# 4/4 [==============================] - 22s 6s/step - loss: 9.1894e-04 - accuracy: 0.2091 - val_loss: 0.1830 - val_accuracy: 0.0045
# Epoch 43/100
# 4/4 [==============================] - 22s 6s/step - loss: 8.8375e-04 - accuracy: 0.1909 - val_loss: 0.1873 - val_accuracy: 0.0045
# Epoch 44/100
# 4/4 [==============================] - 21s 6s/step - loss: 8.6513e-04 - accuracy: 0.1727 - val_loss: 0.1834 - val_accuracy: 0.0045
# Epoch 45/100
# 4/4 [==============================] - 22s 6s/step - loss: 8.1255e-04 - accuracy: 0.2545 - val_loss: 0.1889 - val_accuracy: 0.0068
# Epoch 46/100
# 4/4 [==============================] - 24s 7s/step - loss: 7.6475e-04 - accuracy: 0.2091 - val_loss: 0.1859 - val_accuracy: 0.0068
# Epoch 47/100
# 4/4 [==============================] - 23s 6s/step - loss: 7.5733e-04 - accuracy: 0.2000 - val_loss: 0.1892 - val_accuracy: 0.0068
# Epoch 48/100
# 4/4 [==============================] - 22s 6s/step - loss: 7.2226e-04 - accuracy: 0.2545 - val_loss: 0.1891 - val_accuracy: 0.0068
# Epoch 49/100
# 4/4 [==============================] - 22s 6s/step - loss: 7.2008e-04 - accuracy: 0.2364 - val_loss: 0.1881 - val_accuracy: 0.0045
# Epoch 50/100
# 4/4 [==============================] - 22s 6s/step - loss: 6.9430e-04 - accuracy: 0.1636 - val_loss: 0.1922 - val_accuracy: 0.0045
# Epoch 51/100
# 4/4 [==============================] - 23s 7s/step - loss: 6.9418e-04 - accuracy: 0.2091 - val_loss: 0.1891 - val_accuracy: 0.0045
# Epoch 52/100
# 4/4 [==============================] - 23s 7s/step - loss: 6.8801e-04 - accuracy: 0.1909 - val_loss: 0.1899 - val_accuracy: 0.0045
# Epoch 53/100
# 4/4 [==============================] - 22s 6s/step - loss: 6.6902e-04 - accuracy: 0.1818 - val_loss: 0.1924 - val_accuracy: 0.0045
# Epoch 54/100
# 4/4 [==============================] - 22s 6s/step - loss: 6.5888e-04 - accuracy: 0.3182 - val_loss: 0.1924 - val_accuracy: 0.0045
# Epoch 55/100
# 4/4 [==============================] - 22s 6s/step - loss: 6.5002e-04 - accuracy: 0.2364 - val_loss: 0.1926 - val_accuracy: 0.0045
# Epoch 56/100
# 4/4 [==============================] - 22s 6s/step - loss: 6.3927e-04 - accuracy: 0.2000 - val_loss: 0.1911 - val_accuracy: 0.0045
# Epoch 57/100
# 4/4 [==============================] - 22s 6s/step - loss: 6.3077e-04 - accuracy: 0.2545 - val_loss: 0.1949 - val_accuracy: 0.0045
# Epoch 58/100
# 4/4 [==============================] - 22s 6s/step - loss: 6.2785e-04 - accuracy: 0.2545 - val_loss: 0.1941 - val_accuracy: 0.0045
# Epoch 59/100
# 4/4 [==============================] - 21s 6s/step - loss: 6.2554e-04 - accuracy: 0.2364 - val_loss: 0.1931 - val_accuracy: 0.0045
# Epoch 60/100
# 4/4 [==============================] - 21s 6s/step - loss: 5.9999e-04 - accuracy: 0.3000 - val_loss: 0.1949 - val_accuracy: 0.0023
# Epoch 61/100
# 4/4 [==============================] - 22s 6s/step - loss: 6.0751e-04 - accuracy: 0.2364 - val_loss: 0.1930 - val_accuracy: 0.0045
# Epoch 62/100
# 4/4 [==============================] - 21s 6s/step - loss: 6.0706e-04 - accuracy: 0.2727 - val_loss: 0.1947 - val_accuracy: 0.0023
# Epoch 63/100
# 4/4 [==============================] - 22s 6s/step - loss: 6.0018e-04 - accuracy: 0.2818 - val_loss: 0.1938 - val_accuracy: 0.0045
# Epoch 64/100
# 4/4 [==============================] - 23s 7s/step - loss: 5.9384e-04 - accuracy: 0.2818 - val_loss: 0.1938 - val_accuracy: 0.0045
# Epoch 65/100
# 4/4 [==============================] - 21s 6s/step - loss: 5.8554e-04 - accuracy: 0.2091 - val_loss: 0.1932 - val_accuracy: 0.0023
# Epoch 66/100
# 4/4 [==============================] - 22s 6s/step - loss: 5.6362e-04 - accuracy: 0.3182 - val_loss: 0.1945 - val_accuracy: 0.0023
# Epoch 67/100
# 4/4 [==============================] - 22s 6s/step - loss: 5.5008e-04 - accuracy: 0.2636 - val_loss: 0.1933 - val_accuracy: 0.0023
# Epoch 68/100
# 4/4 [==============================] - 21s 6s/step - loss: 5.6579e-04 - accuracy: 0.2909 - val_loss: 0.1964 - val_accuracy: 0.0023
# Epoch 69/100
# 4/4 [==============================] - 22s 6s/step - loss: 5.5528e-04 - accuracy: 0.2727 - val_loss: 0.1941 - val_accuracy: 0.0023
# Epoch 70/100
# 4/4 [==============================] - 22s 6s/step - loss: 5.4571e-04 - accuracy: 0.3727 - val_loss: 0.1954 - val_accuracy: 0.0023
# Epoch 71/100
# 4/4 [==============================] - 22s 6s/step - loss: 5.4949e-04 - accuracy: 0.3273 - val_loss: 0.1947 - val_accuracy: 0.0045
# Epoch 72/100
# 4/4 [==============================] - 22s 6s/step - loss: 5.3586e-04 - accuracy: 0.3364 - val_loss: 0.1953 - val_accuracy: 0.0023
# Epoch 73/100
# 4/4 [==============================] - 22s 6s/step - loss: 5.3238e-04 - accuracy: 0.3182 - val_loss: 0.1922 - val_accuracy: 0.0023
# Epoch 74/100
# 4/4 [==============================] - 22s 6s/step - loss: 5.2864e-04 - accuracy: 0.3727 - val_loss: 0.1948 - val_accuracy: 0.0023
# Epoch 75/100
# 4/4 [==============================] - 22s 6s/step - loss: 5.3478e-04 - accuracy: 0.3273 - val_loss: 0.1957 - val_accuracy: 0.0023
# Epoch 76/100
# 4/4 [==============================] - 23s 7s/step - loss: 5.1877e-04 - accuracy: 0.3000 - val_loss: 0.1938 - val_accuracy: 0.0023
# Epoch 77/100
# 4/4 [==============================] - 23s 7s/step - loss: 5.1679e-04 - accuracy: 0.3364 - val_loss: 0.1946 - val_accuracy: 0.0023
# Epoch 78/100
# 4/4 [==============================] - 22s 6s/step - loss: 5.1801e-04 - accuracy: 0.3273 - val_loss: 0.1955 - val_accuracy: 0.0023
# Epoch 79/100
# 4/4 [==============================] - 23s 7s/step - loss: 5.2269e-04 - accuracy: 0.3182 - val_loss: 0.1967 - val_accuracy: 0.0023
# Epoch 80/100
# 4/4 [==============================] - 22s 6s/step - loss: 5.0186e-04 - accuracy: 0.3091 - val_loss: 0.1954 - val_accuracy: 0.0023
# Epoch 81/100
# 4/4 [==============================] - 22s 6s/step - loss: 5.1643e-04 - accuracy: 0.3818 - val_loss: 0.1952 - val_accuracy: 0.0023
# Epoch 82/100
# 4/4 [==============================] - 23s 7s/step - loss: 5.0274e-04 - accuracy: 0.3273 - val_loss: 0.1990 - val_accuracy: 0.0023
# Epoch 83/100
# 4/4 [==============================] - 23s 7s/step - loss: 5.0654e-04 - accuracy: 0.3909 - val_loss: 0.1971 - val_accuracy: 0.0023
# Epoch 84/100
# 4/4 [==============================] - 23s 7s/step - loss: 4.9798e-04 - accuracy: 0.2818 - val_loss: 0.1992 - val_accuracy: 0.0023
# Epoch 85/100
# 4/4 [==============================] - 23s 7s/step - loss: 4.9237e-04 - accuracy: 0.3273 - val_loss: 0.1976 - val_accuracy: 0.0023
# Epoch 86/100
# 4/4 [==============================] - 23s 7s/step - loss: 4.9469e-04 - accuracy: 0.3455 - val_loss: 0.1962 - val_accuracy: 0.0045
# Epoch 87/100
# 4/4 [==============================] - 23s 7s/step - loss: 4.8360e-04 - accuracy: 0.3364 - val_loss: 0.1994 - val_accuracy: 0.0045
# Epoch 88/100
# 4/4 [==============================] - 23s 7s/step - loss: 4.9119e-04 - accuracy: 0.3818 - val_loss: 0.1964 - val_accuracy: 0.0023
# Epoch 89/100
# 4/4 [==============================] - 22s 6s/step - loss: 4.7978e-04 - accuracy: 0.4364 - val_loss: 0.1976 - val_accuracy: 0.0023
# Epoch 90/100
# 4/4 [==============================] - 23s 7s/step - loss: 4.9084e-04 - accuracy: 0.3273 - val_loss: 0.2006 - val_accuracy: 0.0023
# Epoch 91/100
# 4/4 [==============================] - 23s 7s/step - loss: 4.9948e-04 - accuracy: 0.3636 - val_loss: 0.1987 - val_accuracy: 0.0045
# Epoch 92/100
# 4/4 [==============================] - 22s 6s/step - loss: 4.9452e-04 - accuracy: 0.3909 - val_loss: 0.1959 - val_accuracy: 0.0023
# Epoch 93/100
# 4/4 [==============================] - 22s 6s/step - loss: 5.0821e-04 - accuracy: 0.4182 - val_loss: 0.1981 - val_accuracy: 0.0023
# Epoch 94/100
# 4/4 [==============================] - 23s 7s/step - loss: 5.1646e-04 - accuracy: 0.3455 - val_loss: 0.1981 - val_accuracy: 0.0023
# Epoch 95/100
# 4/4 [==============================] - 23s 7s/step - loss: 5.1535e-04 - accuracy: 0.4273 - val_loss: 0.2028 - val_accuracy: 0.0023
# Epoch 96/100
# 4/4 [==============================] - 23s 7s/step - loss: 5.0788e-04 - accuracy: 0.3909 - val_loss: 0.1997 - val_accuracy: 0.0045
# Epoch 97/100
# 4/4 [==============================] - 23s 7s/step - loss: 5.1035e-04 - accuracy: 0.4182 - val_loss: 0.2021 - val_accuracy: 0.0023
# Epoch 98/100
# 4/4 [==============================] - 22s 6s/step - loss: 5.1140e-04 - accuracy: 0.3273 - val_loss: 0.2010 - val_accuracy: 0.0023
# Epoch 99/100
# 4/4 [==============================] - 22s 6s/step - loss: 4.9125e-04 - accuracy: 0.3273 - val_loss: 0.2023 - val_accuracy: 0.0045
# Epoch 100/100
# 4/4 [==============================] - 23s 7s/step - loss: 5.0073e-04 - accuracy: 0.3909 - val_loss: 0.2021 - val_accuracy: 0.0023

# %% [markdown]
# # Visualización de los Accuracy y Loss

# %%
visualize_training_results(res)

# %% [markdown]
# # Visualización de las predicciones

# %% [markdown]
# ### Validación del modelo

# %% [markdown]
# Diferencia entre los precios de cierre reales y los precios previstos

# %%
# Transformar los valores a su precio original
actual = pd.DataFrame(close_scaler.inverse_transform(df[["Close"]]), 
                      index=df.index, 
                      columns=[df.columns[0]])

# Valores predichos 
predictions = validater(n_per_in, n_per_out)

# Imprimir el RMSE
print("RMSE:", val_rmse(actual, predictions))
    
# Plotting
plt.figure(figsize=(18,8))

# Plotting those predictions
plt.plot(predictions, label='Predicción')

# Plotting the actual values
plt.plot(actual, label='Actual')

plt.title(f"Predicción vs Precio de cierre actual")
plt.xlabel("Año")
plt.ylabel("Precio")
plt.legend()
plt.xlim('2017-12', '2019-12')
plt.show()
# Out:
# RMSE: 26.785768067183
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\users\odra\appdata\local\programs\python\python39\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1504         try:
# -> 1505             ret = self.converter.convert(x, self.units, self)
#    1506         except Exception as e:
#
# c:\users\odra\appdata\local\programs\python\python39\lib\site-packages\matplotlib\dates.py in convert(value, unit, axis)
#    1872         """
# -> 1873         return date2num(value)
#    1874
#
# c:\users\odra\appdata\local\programs\python\python39\lib\site-packages\matplotlib\dates.py in date2num(d)
#     421             return d
# --> 422         tzi = getattr(d[0], 'tzinfo', None)
#     423         if tzi is not None:
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17268/2095225673.py in <module>
#      23 plt.ylabel("Precio")
#      24 plt.legend()
# ---> 25 plt.xlim('2017-12', '2019-12')
#      26 plt.show()
#
# c:\users\odra\appdata\local\programs\python\python39\lib\site-packages\matplotlib\pyplot.py in xlim(*args, **kwargs)
#    1718     if not args and not kwargs:
#    1719         return ax.get_xlim()
# -> 1720     ret = ax.set_xlim(*args, **kwargs)
#    1721     return ret
#    1722
#
# c:\users\odra\appdata\local\programs\python\python39\lib\site-packages\matplotlib\axes\_base.py in set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3520
#    3521         self._process_unit_info([("x", (left, right))], convert=False)
# -> 3522         left = self._validate_converted_limits(left, self.convert_xunits)
#    3523         right = self._validate_converted_limits(right, self.convert_xunits)
#    3524
#
# c:\users\odra\appdata\local\programs\python\python39\lib\site-packages\matplotlib\axes\_base.py in _validate_converted_limits(self, limit, convert)
#    3434         """
#    3435         if limit is not None:
# -> 3436             converted_limit = convert(limit)
#    3437             if (isinstance(converted_limit, Real)
#    3438                     and not np.isfinite(converted_limit)):
#
# c:\users\odra\appdata\local\programs\python\python39\lib\site-packages\matplotlib\artist.py in convert_xunits(self, x)
#     201         if ax is None or ax.xaxis is None:
#     202             return x
# --> 203         return ax.xaxis.convert_units(x)
#     204
#     205     def convert_yunits(self, y):
#
# c:\users\odra\appdata\local\programs\python\python39\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1505             ret = self.converter.convert(x, self.units, self)
#    1506         except Exception as e:
# -> 1507             raise munits.ConversionError('Failed to convert value(s) to axis '
#    1508                                          f'units: {x!r}') from e
#    1509         return ret
#
# ConversionError: Failed to convert value(s) to axis units: '2017-12'

# %% [markdown]
# # Predecir / pronosticar los precios futuros

# %%
# Predicción de los días más recientes desde el DF original
yhat = model.predict(np.array(df.tail(n_per_in)).reshape(1, n_per_in, n_features))

# Transformar los valores predichos a su formato original
yhat = close_scaler.inverse_transform(yhat)[0]

# Creando un DF de los precios previstos
preds = pd.DataFrame(yhat, 
                     index=pd.date_range(start=df.index[-1]+timedelta(days=1), 
                                         periods=len(yhat), 
                                         freq="B"), 
                     columns=[df.columns[0]])

# Número de períodos atrás 
pers = n_per_in

# Transformar los valores reales a su precio original
actual = pd.DataFrame(close_scaler.inverse_transform(df[["Close"]].tail(pers)), 
                      index=df.Close.tail(pers).index, 
                      columns=[df.columns[0]]).append(preds.head(1))

# Imprimir los precios previstos
print(preds)

# Plotting
plt.figure(figsize=(16,6))
plt.plot(actual, label="Precios Actuales")
plt.plot(preds, label="Predicción de Precios")
plt.ylabel("Precio")
plt.xlabel("Años")
plt.title(f"Previsión de los próximos {len(yhat)} días")
plt.legend()
plt.show()
# Out:
#                  Close
# 2020-01-06  324.836182
# 2020-01-07  300.647308
# 2020-01-08  330.787476
# 2020-01-09  315.786804
# 2020-01-10  335.008423
# ...                ...
# 2020-09-07  221.958557
# 2020-09-08  231.371735
# 2020-09-09  224.242508
# 2020-09-10  229.225754
# 2020-09-11  226.967636
#
# [180 rows x 1 columns]

# %%
# Guardar como archivo CSV
preds.to_csv('Prediccion_LSTM.csv', encoding='utf-8', sep='_')
